# %% [markdown]
# # 🚀 EDA + Feature Engineering Grandmaster Masterclass
#
# Built from the CampusX DSMP curriculum.
#
# Goal:
# - Learn EDA like a Kaggle Grandmaster
# - Learn Feature Engineering like an ML Engineer
# - Build intuition, not memorization
# - Create a reusable revision bible
#
# ---
#
# # The Data Science Workflow
#
# Raw Data
# ↓
# Data Assessment
# ↓
# Data Cleaning
# ↓
# EDA
# ↓
# Feature Engineering
# ↓
# Feature Selection
# ↓
# Modeling
# ↓
# Evaluation

# %% [markdown]
# # Part 1: Data Assessment
#
# ## Questions
#
# - Shape?
# - Data types?
# - Missing values?
# - Duplicates?
# - Invalid values?
# - Target variable?
# - Leakage?
#
# ## Checklist
#
# ```python
# df.shape
# df.info()
# df.describe()
# df.sample(5)
# df.isnull().sum()
# df.duplicated().sum()
# ```

# %% [markdown]
# # Part 2: Data Cleaning
#
# ## Quality Issues
#
# - Missing values
# - Wrong datatype
# - Duplicates
# - Outliers
# - Invalid entries
#
# ## Tidiness Issues
#
# - Multiple variables in one column
# - Multiple tables
# - Wide vs Long format
#
# ## Golden Rule
#
# Never perform EDA before basic cleaning.

# %% [markdown]
# # Part 3: Exploratory Data Analysis (EDA)
#
# EDA answers 4 questions:
#
# 1. What exists?
# 2. What differs?
# 3. What relates?
# 4. What predicts?
#
# ---
#
# # Univariate Analysis
#
# Numerical:
# - histplot
# - kdeplot
# - ecdfplot
# - boxplot
#
# Categorical:
# - countplot
# - value_counts
#
# Goals:
# - distribution
# - skewness
# - outliers
# - imbalance

# %% [markdown]
# # Bivariate Analysis
#
# Numerical vs Numerical
#
# - scatterplot
# - regplot
# - jointplot
#
# Questions:
# - Correlation?
# - Trend?
# - Linear relationship?
#
# Categorical vs Numerical
#
# - boxplot
# - violinplot
# - boxenplot
# - pointplot
#
# Questions:
# - Do groups differ?
# - Are means different?
# - Are distributions different?
#
# Categorical vs Categorical
#
# - crosstab
# - heatmap
#
# Questions:
# - Association?
# - Dependency?

# %% [markdown]
# # Multivariate Analysis
#
# Tools:
#
# - hue
# - size
# - style
# - pairplot
# - PairGrid
# - FacetGrid
# - JointGrid
#
# Goal:
#
# Find hidden interactions between variables.

# %% [markdown]
# # Correlation Analysis
#
# ## Heatmap
#
# Shows correlations.
#
# ## Clustermap
#
# Shows correlations + feature groups.
#
# ## Detect
#
# - Multicollinearity
# - Redundant features
# - Feature clusters
#
# Warning:
#
# Correlation ≠ Causation

# %% [markdown]
# # Outlier Analysis
#
# Methods:
#
# - Boxplot
# - IQR
# - Z-score
# - Percentile
#
# Questions:
#
# - Is it error?
# - Is it genuine rare event?
# - Is it important signal?

# %% [markdown]
# # Missing Value Analysis
#
# Types:
#
# 1. MCAR
# 2. MAR
# 3. MNAR
#
# Strategies:
#
# - Drop rows
# - Drop columns
# - Mean
# - Median
# - Mode
# - Random Imputation
# - KNN Imputer
# - Iterative Imputer (MICE)
#
# Always analyze missingness before filling.

# %% [markdown]
# # Feature Engineering Masterclass
#
# Feature Engineering = Creating Better Inputs
#
# 4 Categories
#
# 1. Transformation
# 2. Construction
# 3. Extraction
# 4. Selection

# %% [markdown]
# # Missing Value Features
#
# Techniques:
#
# - Mean Imputation
# - Median Imputation
# - Mode Imputation
# - Missing Category
# - Random Imputation
# - KNN Imputation
# - Iterative Imputation
# - Missing Indicator
#
# Interview Question:
#
# When should median be preferred over mean?
# Answer:
# Skewed distributions.

# %% [markdown]
# # Encoding Categorical Variables
#
# ## Nominal
#
# - One Hot Encoding
#
# ## Ordinal
#
# - Ordinal Encoding
#
# ## High Cardinality
#
# - Target Encoding
#
# Rules:
#
# Few categories -> OHE
#
# Ordered categories -> Ordinal Encoding

# %% [markdown]
# # Feature Transformation
#
# Purpose:
#
# Make distributions easier for models.
#
# Methods:
#
# - Log Transform
# - Reciprocal Transform
# - Square Root Transform
# - Box-Cox
# - Yeo-Johnson
#
# When?
#
# Skewed numerical columns.

# %% [markdown]
# # Feature Construction
#
# Create new features.
#
# Examples:
#
# Age from DOB
#
# Price_per_sqft
#
# Luxury_score
#
# Room_density
#
# Interaction features
#
# This is where most Kaggle gains come from.

# %% [markdown]
# # Feature Extraction
#
# Examples:
#
# Text -> TF-IDF
#
# Images -> CNN embeddings
#
# Datetime ->
#
# - day
# - month
# - year
# - weekday
# - weekend
#
# Address -> city/state
#
# Feature Extraction = converting raw information into usable information.

# %% [markdown]
# # Feature Selection
#
# ## Filter Methods
#
# - Variance Threshold
# - Correlation
# - Chi-square
# - ANOVA
#
# ## Wrapper Methods
#
# - Forward Selection
# - Backward Elimination
# - Exhaustive Search
#
# ## Embedded Methods
#
# - LASSO
# - Tree Importance
# - Random Forest
# - Gradient Boosting
#
# ## RFE
#
# Recursive Feature Elimination

# %% [markdown]
# # EDA Decision Tree
#
# One Column?
#
# → histplot
# → kdeplot
# → countplot
#
# Two Numerical?
#
# → scatterplot
# → regplot
#
# Category vs Numeric?
#
# → boxplot
# → violinplot
# → pointplot
#
# Correlation?
#
# → heatmap
# → clustermap
#
# Many Features?
#
# → pairplot
# → PairGrid
# → FacetGrid

# %% [markdown]
# # Kaggle Grandmaster EDA Checklist
#
# □ Missing Values
#
# □ Target Distribution
#
# □ Class Imbalance
#
# □ Numerical Analysis
#
# □ Categorical Analysis
#
# □ Correlation Matrix
#
# □ Outlier Detection
#
# □ Feature Relationships
#
# □ Leakage Detection
#
# □ Feature Engineering
#
# □ Feature Selection
#
# □ Baseline Model
#
# □ Error Analysis
#
# This checklist should become automatic.

# %% [markdown]
# # Active Recall Questions
#
# 1. Difference between PairPlot and PairGrid?
#
# 2. Why use Clustermap?
#
# 3. Mean vs Median Imputation?
#
# 4. When use Log Transform?
#
# 5. What is Data Leakage?
#
# 6. Difference between OHE and Ordinal Encoding?
#
# 7. Why check target distribution first?
#
# 8. Why can correlation mislead?
#
# 9. How detect multicollinearity?
#
# 10. What creates the largest Kaggle gains?
# Answer:
# Feature Engineering.
