# %% [markdown]
# # 🧠 Seaborn Grandmaster EDA Codex
#
# This notebook is designed for:
#
# - Kaggle Competitions
# - CampusX DSMP
# - Industry EDA
# - Interview Revision
# - Fast Recall
#
# Goal:
#
# When you see a dataset, instantly know:
#
# 1. Which question to ask
# 2. Which plot to use
# 3. What insight to extract
# 4. What action to take
#
# ---
#
# # Master Decision Tree
#
# ```text
# Dataset
# │
# ├── One Variable?
# │   ├── histplot
# │   ├── kdeplot
# │   ├── ecdfplot
# │
# ├── Two Numeric?
# │   ├── scatterplot
# │   ├── regplot
# │   └── jointplot
# │
# ├── Category vs Numeric?
# │   ├── boxplot
# │   ├── violinplot
# │   ├── boxenplot
# │   ├── stripplot
# │   └── swarmplot
# │
# ├── Time?
# │   └── lineplot
# │
# ├── Correlation?
# │   ├── heatmap
# │   └── clustermap
# │
# └── Many Features?
#     ├── pairplot
#     ├── PairGrid
#     └── FacetGrid
# ```

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

sns.set_theme(style='whitegrid')

tips = sns.load_dataset('tips')
iris = sns.load_dataset('iris')
penguins = sns.load_dataset('penguins')
titanic = sns.load_dataset('titanic')
flights = sns.load_dataset('flights')

# %% [markdown]
# # Histplot
#
# ### Why?
# Distribution & Skewness
#
#
# ### Example

# %%
sns.histplot(tips['total_bill'], kde=True)
plt.show()

# %% [markdown]
# # KDEPlot
#
# ### Why?
# Smooth Distribution
#
#
# ### Example

# %%
sns.kdeplot(tips['total_bill'], fill=True)
plt.show()

# %% [markdown]
# # ECDFPlot
#
# ### Why?
# Percent below X
#
#
#
# ### Example

# %%
sns.ecdfplot(tips['total_bill'])
plt.show()

# %% [markdown]
# # CountPlot
#
# ### Why?
# Class Imbalance
#
#
# ### Example

# %%
sns.countplot(data=titanic,x='survived')
plt.show()

# %% [markdown]
# # ScatterPlot
#
# ### Why?
# Relationship
#
# ### Example

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='sex')
plt.show()

# %% [markdown]
# # RegPlot
#
# ### Why?
# Trend
#
#
#
# ### Example

# %%
sns.regplot(data=tips,x='total_bill',y='tip')
plt.show()

# %% [markdown]
# # LinePlot
#
# ### Why?
# Time Series
#
#
# ### Example

# %%
sns.lineplot(data=flights,x='year',y='passengers')
plt.show()

# %% [markdown]
# # BoxPlot
#
# ### Why?
# Outliers
#
#
# ### Example

# %%
sns.boxplot(data=tips,x='day',y='total_bill')
plt.show()

# %% [markdown]
# # ViolinPlot
#
# ### Why?
# Shape + Outliers
#
# ### Example

# %%
sns.violinplot(data=tips,x='day',y='total_bill')
plt.show()

# %% [markdown]
# # BoxenPlot
#
# ### Why?
# Large Dataset Outliers
#
#
# ### Example

# %%
sns.boxenplot(data=tips,x='day',y='total_bill')
plt.show()

# %% [markdown]
# # StripPlot
#
# ### Why?
# See Every Point
#
#
#
# ### Example

# %%
sns.stripplot(data=tips,x='day',y='total_bill')
plt.show()

# %% [markdown]
# # SwarmPlot
#
# ### Why?
# No Overlap
#
# ### Example

# %%
sns.swarmplot(data=tips,x='day',y='total_bill')
plt.show()

# %% [markdown]
# # BarPlot
#
# ### Why?
# Mean Comparison
#
#
#
# ### Example

# %%
sns.barplot(data=tips,x='day',y='total_bill')
plt.show()

# %% [markdown]
# # PointPlot
#
# ### Why?
# Clean Mean Comparison
#
# ### Example

# %%
sns.pointplot(data=tips,x='day',y='total_bill')
plt.show()

# %% [markdown]
# # PairPlot
#
# ### Why?
# Everything vs Everything
#
#
# ### Example

# %%
sns.pairplot(iris,hue='species')
plt.show()

# %% [markdown]
# # JointPlot
#
# ### Why?
# Relationship + Distribution
#
#
# ### Example

# %%
sns.jointplot(data=tips,x='total_bill',y='tip')
plt.show()

# %% [markdown]
# # Heatmaps
#
# Memory Trick:
#
# HEAT = CORRELATION TEMPERATURE
#
# Positive = Hot
#
# Negative = Cold
#
# Use for feature selection.

# %%
corr=tips.select_dtypes(include='number').corr()

sns.heatmap(corr,annot=True,cmap='coolwarm')
plt.show()

# %% [markdown]
# # Advanced Heatmap Trick
#
# Kaggle Standard:
#
# Hide duplicate triangle.

# %%
corr=tips.select_dtypes(include='number').corr()

mask=np.triu(np.ones_like(corr,dtype=bool))

sns.heatmap(
    corr,
    mask=mask,
    annot=True,
    cmap='coolwarm'
)
plt.show()

# %% [markdown]
# # ClusterMap
#
# Memory:
#
# Heatmap with Intelligence
#
# Groups similar features automatically.

# %%
corr=penguins.select_dtypes(include='number').corr()

sns.clustermap(corr,annot=True,cmap='coolwarm')
plt.show()

# %% [markdown]
# # FacetGrid
#
# Question:
#
# What happens separately inside groups?

# %%
g=sns.FacetGrid(tips,col='sex')
g.map(sns.histplot,'total_bill')
plt.show()

# %% [markdown]
# # PairGrid
#
# PairPlot on steroids.
#
# gives manual control for which plots to be performed in upper  (above diag), lower, diag.

# %%
g=sns.PairGrid(iris)

g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)
g.map_diag(sns.histplot)

plt.show()

# %% [markdown]
# # LmPlot
#
# Regression + Grouping
#
# Kaggle favorite.

# %%
sns.lmplot(
    data=tips,
    x='total_bill',
    y='tip',
    hue='sex'
)
plt.show()

# %% [markdown]
# # Titanic Mini EDA
#
# Real Kaggle Thinking
#
# Questions:
#
# 1. Target imbalance?
# 2. Missing values?
# 3. Survival by Sex?
# 4. Survival by Class?
# 5. Important correlations?

# %%
titanic.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# deck           688
# age            177
# embarked         2
# embark_town      2
# sex              0
# pclass           0
# survived         0
# fare             0
# parch            0
# sibsp            0
# dtype: int64

# %%
sns.countplot(data=titanic,x='survived')
plt.show()

# %%
sns.countplot(data=titanic,x='sex',hue='survived')
plt.show()

# %%
sns.countplot(data=titanic,x='class',hue='survived')
plt.show()

# %% [markdown]
# # 20 Kaggle EDA Rules
#
# 1. Missing values first
# 2. Target analysis first
# 3. Check imbalance
# 4. Never trust correlation blindly
# 5. Pairplot only on selected columns
# 6. Use hue aggressively
# 7. Boxplot before removing outliers
# 8. Outlier != bad data
# 9. Correlation != causation
# 10. Look for leakage
# 11. Check duplicates
# 12. Understand target distribution
# 13. Compare train/test distributions
# 14. Plot before feature engineering
# 15. Visualize skewness
# 16. Use log transforms wisely
# 17. Study feature interactions
# 18. Build baseline quickly
# 19. Simpler model first
# 20. Good EDA beats fancy models
