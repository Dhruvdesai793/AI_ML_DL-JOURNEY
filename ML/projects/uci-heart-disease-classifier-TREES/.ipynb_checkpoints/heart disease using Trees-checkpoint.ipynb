# %% [markdown]
# # My Mistakes were:
# 1. ## Forgetting to show Exploratory analysis
# 2. ## bcos of forgetting exploratory analysis i didn't convert Target values [0,1,2,3,4] to simple binary [0,1] this would give alot more better accuracy.
# 3. ## Didn't implement RandomSearchCv or GridSearchCv for hyperparam tuning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

import statistics

# %%
# %pip install ucimlrepo
# Out:
# ...
#   Using cached ucimlrepo-0.0.7-py3-none-any.whl.metadata (5.5 kB)
# ...
# Using cached ucimlrepo-0.0.7-py3-none-any.whl (8.0 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
heart_disease = fetch_ucirepo(id=45) 
  
# data (as pandas dataframes) 
X = heart_disease.data.features 
y = heart_disease.data.targets 
  
# metadata 
print(heart_disease.metadata) 
  
# variable information 
print(heart_disease.variables)
# Out:
# {'uci_id': 45, 'name': 'Heart Disease', 'repository_url': 'https://archive.ics.uci.edu/dataset/45/heart+disease', 'data_url': 'https://archive.ics.uci.edu/static/public/45/data.csv', 'abstract': '4 databases: Cleveland, Hungary, Switzerland, and the VA Long Beach', 'area': 'Health and Medicine', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 303, 'num_features': 13, 'feature_types': ['Categorical', 'Integer', 'Real'], 'demographics': ['Age', 'Sex'], 'target_col': ['num'], 'index_col': None, 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 1989, 'last_updated': 'Fri Nov 03 2023', 'dataset_doi': '10.24432/C52P4X', 'creators': ['Andras Janosi', 'William Steinbrunn', 'Matthias Pfisterer', 'Robert Detrano'], 'intro_paper': {'ID': 231, 'type': 'NATIVE', 'title': 'International application of a new probability algorithm for the diagnosis of coronary artery disease.', 'authors': 'R. Detrano, A. Jánosi, W. Steinbrunn,
# ...

# %%
X.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal'],
#       dtype='str')

# %%
X.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          4
# thal        2
# dtype: int64

# %%
y.isnull().sum()
# Out:
# num    0
# dtype: int64

# %%
y.head()
X['ca'] = X.ca.fillna(statistics.mode(X.ca))
X['thal'] = X.thal.fillna(statistics.mode(X.thal))

X.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# dtype: int64

# %%
X.head()
print(X.shape)
# Out:
# (303, 13)

# %%
categorical_feats = ['thal', 'slope', 'sex', 'cp', 'fbs','restecg', 'exang']

# trees don't need scaling.
categorical_preprocessor = Pipeline(
    steps = [("onehot", OneHotEncoder(handle_unknown = 'ignore'))]
           )



preprocessor  = ColumnTransformer( transformers = [ ('categorical',categorical_preprocessor,categorical_feats) ] )
X.shape
# Out:
# (303, 13)

# %%
pipe = make_pipeline(preprocessor, DecisionTreeClassifier(max_depth=100, ccp_alpha= 0.016) )

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    random_state=42,
    test_size=0.25,
    stratify=y,
)

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('categorical',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['thal', 'slope', 'sex', 'cp',
#                                                    'fbs', 'restecg',
#                                                    'exang'])])),
#                 ('decisiontreeclassifier',
#                  DecisionTreeClassifier(ccp_alpha=0.016, max_depth=100))])

# %%
y_pred = pipe.predict(X_test)

# %%
import seaborn as sns

cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, annot=True, cmap='BuPu')
plt.xlabel('predictions')
plt.ylabel('true value')
plt.show()

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

print(f1_score(y_test, y_pred, average='weighted'))
# Out:
# 0.4695683490250553

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.5526315789473685

# %%
precision_score(y_test, y_pred, average='weighted')
# Out:
# /home/blixture/anaconda3/envs/code/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 0.4139676113360324

# %%
recall_score(y_test, y_pred, average='weighted')
# Out:
# 0.5526315789473685

# %%
print(y.value_counts())
print(y.nunique())
# Out:
# num
# 0      164
# 1       55
# 2       36
# 3       35
# 4       13
# Name: count, dtype: int64
# num    5
# dtype: int64

# %%
pipe.score(X_train, y_train)
# Out:
# 0.5991189427312775

# %%
pipe.score(X_test, y_test)
# Out:
# 0.5526315789473685

# %% [markdown]
# ## It has very bad scores. lets try using Stratified K-Fold

# %%
from sklearn.model_selection import StratifiedKFold

skf = StratifiedKFold(
    n_splits = 5,
    shuffle = True,
    random_state=42
)

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(
    pipe,
    X,
    y,
    cv = skf,
    scoring='accuracy'
)

print(scores)

print(scores.mean())
# Out:
# [0.60655738 0.55737705 0.50819672 0.56666667 0.56666667]
# 0.5610928961748634
